# %% [markdown]
# # Machinaal Leren - Sprint 2: Text Data
#
# ## Task:
# What insights can we gain from the text data (title, description and reviews) ?
#
# Possible tasks:
# * Detect duplicate listings
# * Extract keywords from reviews / descriptions
# * Automatically make a list of positive and negative points for a listing based on the reviews
# * Recognize listings from the same owner
# * Detect anomalies (listings/ reviews that are very different from other listings/ reviews)
# * Detect reviews that are very similar
# * Perform sentiment analysis on a review
# * ...

# %% [markdown]
# ## Work table

# %% [markdown]
# |Task|Peter Bonnarens|Philip Kukoba|Lennert Franssens|
# |------|------|------|------|
# |Detect duplicate listings  |X  |X  | X |
# |Extract keywords  |_  |_  | _ |
# |Automatically make a list  |_  |_  | _ |
# |Recognize listings from the same owner  |_  |_  | _ |
# |Detect anomalies  |_  |_  | _ |
# |Detect reviews that are very similar  |_  |_  | _ |
# |Perform sentiment analysis on a review  |_  |_  | _ |

# %% [markdown]
# # 1 - Loading the dataset

# %%
# %matplotlib inline

# imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd  
import seaborn as sns 
from matplotlib import rcParams
import warnings

# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', -1)
# delete warnings from output
warnings.filterwarnings('ignore')

# figure size in inches
plt.rcParams['figure.figsize'] = 15, 12

# loading the datasets into pandas dataframes
reviews = pd.read_csv("data/reviews.csv")
listings = pd.read_csv("data/listings.csv")

# %%
reviews.head()
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0      187870  540088  2011-09-17      1003634      Dominick
# 1      187870  581572  2011-09-29       178012         Nancy
# 2      187870  715167  2011-11-13      1391583     Charlotte
# 3      187870  834756  2012-01-03      1513484     Ger Y Flo
# 4      187870  855004  2012-01-10      1503813           Max
#
#                                             comments
# 0  This is a very lovely room. The room, bathroom...
# 1  Tamara's place in Ghent was really nice and cl...
# 2  We spend one night at Tamara's and it was perf...
# 3  Pasamos unos dias increibles en Gante, la habi...
# 4  My girlfriend and I had the most wonderful tim...

# %%
listings.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  187870  https://www.airbnb.com/rooms/187870  20210716195504   2021-07-16
# 1  203806  https://www.airbnb.com/rooms/203806  20210716195504   2021-07-16
# 2  204245  https://www.airbnb.com/rooms/204245  20210716195504   2021-07-16
# 3  216715  https://www.airbnb.com/rooms/216715  20210716195504   2021-07-16
# 4  252269  https://www.airbnb.com/rooms/252269  20210716195504   2021-07-16
#
#                                                 name  \
# 0  Luxury studio 'Spiegelhof' in the centre of Ghent
# 1                Flat close to Sint-Pieters Station!
# 2                    Modern studio's in Ghent centre
# 3                                     converted loft
# 4  Large & bright town House - Center Ghent - max 8p
#
#                                          description  \
# 0  The top floor of our house in the center of Gh...
# 1  This well-located and comfortable one-bedroom ...
# 2  <b>The space</b><br />We offer luxury studio's...
# 3  Please read full desription for how to get the...
# 4  bright, spacious, authentic & beautifully rest...
#
#                                neighborhood_overview  \
# 0  We live in a quiet and pleasant neighborhood w...
# 1  The house is located in a dead-end street - so...
# 2                                                NaN
# 3  It's close to all that you will want or need v...
# 4  our neighbourhood is quiet, but nicely vibrati...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/26c46224-795c...   904277
# 1  https://a0.muscache.com/pictures/fe477b7f-93ac...   999847
# 2  https://a0.muscache.com/pictures/1766072/02965...  1003009
# 3  https://a0.muscache.com/pictures/1927009/20760...   911466
# 4  https://a0.muscache.com/pictures/69675b54-3e78...  1195314
#
#                                     host_url  ... review_scores_location  \
# 0   https://www.airbnb.com/users/show/904277  ...                   4.58
# 1   https://www.airbnb.com/users/show/999847  ...                   4.49
# 2  https://www.airbnb.com/users/show/1003009  ...                   4.97
# 3   https://www.airbnb.com/users/show/911466  ...                   4.89
# 4  https://www.airbnb.com/users/show/1195314  ...                   4.98
#
#   review_scores_value license instant_bookable calculated_host_listings_count  \
# 0                4.85     NaN                t                              1
# 1                4.54     NaN                f                              2
# 2                4.63     NaN                f                              2
# 3                4.76     NaN                t                              1
# 4                4.72     NaN                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           2
# 2                                           2
# 3                                           1
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month Unnamed: 74
# 0                                           0              3.61         NaN
# 1                                           0              2.84         NaN
# 2                                           0              0.29         NaN
# 3                                           0              4.31         NaN
# 4                                           0              2.23         NaN
#
# [5 rows x 75 columns]

# %% [markdown]
# Find lines to shift and add them to a mask - we've found that some lines are shifted 1 to the right beginning on the host_id column (that now contains garbage data)

# %%
shifted_lines = listings[pd.to_numeric(listings["host_verifications"], errors='coerce').notnull()].id
mask = listings['id'].isin(shifted_lines)

# shift lines 1 to the left
listings.loc[mask, 'host_since':'reviews_per_month'] = listings.loc[mask, 'host_since':'reviews_per_month'].shift(-1, axis=1)

# %%
listings.drop(['host_response_time','host_response_rate','host_acceptance_rate','host_is_superhost','host_listings_count','host_total_listings_count',
            'host_has_profile_pic','host_identity_verified','latitude','longitude','accommodates','bathrooms','bedrooms','beds','price','minimum_nights',
            'maximum_nights','minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm',
            'maximum_nights_avg_ntm','calendar_updated','has_availability','availability_30','availability_60','availability_90','availability_365',
            'number_of_reviews','number_of_reviews_ltm','number_of_reviews_l30d','first_review','last_review','license','instant_bookable','calculated_host_listings_count',
            'calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms',
            'reviews_per_month'], axis=1)
# Out:
#            id                            listing_url       scrape_id  \
# 0      187870    https://www.airbnb.com/rooms/187870  20210716195504
# 1      203806    https://www.airbnb.com/rooms/203806  20210716195504
# 2      204245    https://www.airbnb.com/rooms/204245  20210716195504
# 3      216715    https://www.airbnb.com/rooms/216715  20210716195504
# 4      252269    https://www.airbnb.com/rooms/252269  20210716195504
# ..        ...                                    ...             ...
# 918  51022259  https://www.airbnb.com/rooms/51022259  20210716195504
# 919  51036302  https://www.airbnb.com/rooms/51036302  20210716195504
# 920  51053223  https://www.airbnb.com/rooms/51053223  20210716195504
# 921  51056846  https://www.airbnb.com/rooms/51056846  20210716195504
# 922  51061671  https://www.airbnb.com/rooms/51061671  20210716195504
#
#     last_scraped                                               name  \
# 0     2021-07-16  Luxury studio 'Spiegelhof' in the centre of Ghent
# 1     2021-07-16                Flat close to Sint-Pieters Station!
# 2     2021-07-16                    Modern studio's in Ghent centre
# 3     2021-07-16                                     converted loft
# 4     2021-07-16  Large & bright town House - Center Ghent - max 8p
# ..           ...                                                ...
# 918   2021-07-16           Full apartment near Sint Pieters Station
# 919   2021-07-16                                   Guesthouse Flora
# 920   2021-07-16  Large modern house 10min from downtown Ghent/Gent
# 921   2021-07-16  Comfort, quiet en green in ancient part of center
# 922   2021-07-16      Comfortable spacious bedroom near shops & uni
#
#                                            description  \
# 0    The top floor of our house in the center of Gh...
# 1    This well-located and comfortable one-bedroom ...
# 2    <b>The space</b><br />We offer luxury studio's...
# 3    Please read full desription for how to get the...
# 4    bright, spacious, authentic & beautifully rest...
# ..                                                 ...
# 918  This is a 2 bedroom apartment.  Guests will en...
# 919  Geniet van de moderne en ouderwetse charme van...
# 920  Just 10 minutes from historic downtown Ghent. ...
# 921                                                NaN
# 922  Gent is a beautiful city. Come and explore thi...
#
#                                  neighborhood_overview  \
# 0    We live in a quiet and pleasant neighborhood w...
# 1    The house is located in a dead-end street - so...
# 2                                                  NaN
# 3    It's close to all that you will want or need v...
# 4    our neighbourhood is quiet, but nicely vibrati...
# ..                                                 ...
# 918  Apartment is located in neighborhood of Sint P...
# 919  De Flora is het meest noordelijke gedeelte van...
# 920                                                NaN
# 921                                                NaN
# 922                                                NaN
#
#                                            picture_url  \
# 0    https://a0.muscache.com/pictures/26c46224-795c...
# 1    https://a0.muscache.com/pictures/fe477b7f-93ac...
# 2    https://a0.muscache.com/pictures/1766072/02965...
# 3    https://a0.muscache.com/pictures/1927009/20760...
# 4    https://a0.muscache.com/pictures/69675b54-3e78...
# ..                                                 ...
# 918   the main station in Ghent. The street is very...
# 919  https://a0.muscache.com/pictures/186f59af-f089...
# 920  https://a0.muscache.com/pictures/7de8d4c4-0155...
# 921  https://a0.muscache.com/pictures/a7faff71-0c08...
# 922  https://a0.muscache.com/pictures/miso/Hosting-...
#
#                                                host_id  \
# 0                                               904277
# 1                                               999847
# 2                                              1003009
# 3                                               911466
# 4                                              1195314
# ..                                                 ...
# 918  https://a0.muscache.com/pictures/47c0402d-8d28...
# 919                                          171955140
# 920                                            2650664
# 921                                           45920980
# 922                                          412643939
#
#                                         host_url  ...  \
# 0       https://www.airbnb.com/users/show/904277  ...
# 1       https://www.airbnb.com/users/show/999847  ...
# 2      https://www.airbnb.com/users/show/1003009  ...
# 3       https://www.airbnb.com/users/show/911466  ...
# 4      https://www.airbnb.com/users/show/1195314  ...
# ..                                           ...  ...
# 918                                     97573561  ...
# 919  https://www.airbnb.com/users/show/171955140  ...
# 920    https://www.airbnb.com/users/show/2650664  ...
# 921   https://www.airbnb.com/users/show/45920980  ...
# 922  https://www.airbnb.com/users/show/412643939  ...
#
#                                              amenities calendar_last_scraped  \
# 0    ["Microwave", "Keypad", "Extra pillows and bla...            2021-07-16
# 1    ["Dishwasher", "Ethernet connection", "Microwa...            2021-07-16
# 2    ["Shampoo", "Wifi", "TV", "Heating", "Dedicate...            2021-07-16
# 3    ["Long term stays allowed", "Microwave", "Cook...            2021-07-16
# 4    ["Hot water kettle", "Dishwasher", "Microwave"...            2021-07-16
# ..                                                 ...                   ...
# 918  ["Microwave", "Fire extinguisher", "Dishes and...            2021-07-16
# 919  ["Hot water kettle", "Microwave", "Extra pillo...            2021-07-16
# 920  ["Baby safety gates", "Dishwasher", "Backyard"...            2021-07-16
# 921  ["Air conditioning", "Paid parking off premise...            2021-07-16
# 922  ["Extra pillows and blankets", "Clothing stora...            2021-07-16
#
#     review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                   4.85                   4.90                      4.95
# 1                   4.59                   4.72                      4.73
# 2                   4.79                   4.73                      4.93
# 3                   4.75                   4.81                      4.90
# 4                   4.89                   4.92                      4.93
# ..                   ...                    ...                       ...
# 918                  NaN                    NaN                       NaN
# 919                  NaN                    NaN                       NaN
# 920                  NaN                    NaN                       NaN
# 921                  NaN                    NaN                       NaN
# 922                  NaN                    NaN                       NaN
#
#     review_scores_checkin review_scores_communication review_scores_location  \
# 0                    4.90                        4.87                   4.58
# 1                    4.80                        4.79                   4.49
# 2                    4.83                        4.70                   4.97
# 3                    4.89                        4.85                   4.89
# 4                    4.92                        4.97                   4.98
# ..                    ...                         ...                    ...
# 918                   NaN                         NaN                    NaN
# 919                   NaN                         NaN                    NaN
# 920                   NaN                         NaN                    NaN
# 921                   NaN                         NaN                    NaN
# 922                   NaN                         NaN                    NaN
#
#     review_scores_value Unnamed: 74
# 0                  4.85         NaN
# 1                  4.54         NaN
# 2                  4.63         NaN
# 3                  4.76         NaN
# 4                  4.72         NaN
# ..                  ...         ...
# 918                 NaN         NaN
# 919                 NaN         NaN
# 920                 NaN         NaN
# 921                 NaN         NaN
# 922                 NaN         NaN
#
# [923 rows x 34 columns]

# %% [markdown]
# Drop all rows without comments.

# %%
reviews = reviews.dropna()

# %%
listings['description'] = listings['description'].str.replace(r'<b>.*?<\/b>', '', regex=True)
listings['description'] = listings['description'].str.replace(r'<[^<>]*>', ' ', regex=True)
listings = listings[listings['description'].notna()]

# %% [markdown]
# ## Detect duplicate listings
# To detect duplicates we compare entries based on the description column. The column should be carefully chosen since e.g. comparing based on the name might mark non-duplicates as duplicates, if both have the same generic name.

# %%
print(listings[listings.duplicated(['description']) == True])
# Out:
#            id                            listing_url       scrape_id  \
# 122   8296779   https://www.airbnb.com/rooms/8296779  20210716195504
# 211  14963441  https://www.airbnb.com/rooms/14963441  20210716195504
# 241  17415990  https://www.airbnb.com/rooms/17415990  20210716195504
# 242  17416223  https://www.airbnb.com/rooms/17416223  20210716195504
# 244  17416437  https://www.airbnb.com/rooms/17416437  20210716195504
# 245  17416518  https://www.airbnb.com/rooms/17416518  20210716195504
# 389  26390559  https://www.airbnb.com/rooms/26390559  20210716195504
# 403  26984036  https://www.airbnb.com/rooms/26984036  20210716195504
# 420  28424935  https://www.airbnb.com/rooms/28424935  20210716195504
# 465  32184650  https://www.airbnb.com/rooms/32184650  20210716195504
# 467  32354302  https://www.airbnb.com/rooms/32354302  20210716195504
# 547  36794750  https://www.airbnb.com/rooms/36794750  20210716195504
# 572  38261340  https://www.airbnb.com/rooms/38261340  20210716195504
# 576  38319358  https://www.airbnb.com/rooms/38319358  20210716195504
# 577  38320217  https://www.airbnb.com/rooms/38320217  20210716195504
# 596  38942469  https://www.airbnb.com/rooms/38942469  20210716195504
# 617  39624584  https://www.airbnb.com/rooms/39624584  20210716195504
# 661  42108139  https://www.airbnb.com/rooms/42108139  20210716195504
# 674  42166580  https://www.airbnb.com/rooms/42166580  20210716195504
# 675  42166739  https://www.airbnb.com/rooms/42166739  20210716195504
# 678  42353100  https://www.airbnb.com/rooms/42353100  20210716195504
# 784  45938885  https://www.airbnb.com/rooms/45938885  20210716195504
# 860  49895212  https://www.airbnb.com/rooms/49895212  20210716195504
#
#     last_scraped                                               name  \
# 122   2021-07-16                                       B&B Halewijn
# 211   2021-07-16              Cosy, light vintage design appartment
# 241   2021-07-16                      Edville studio Duplex (2p-4p)
# 242   2021-07-16                 Edville studio Duplex A304 (2p-4p)
# 244   2021-07-16                                     Edville Studio
# 245   2021-07-16                                     Edville Studio
# 389   2021-07-16        Luxe BNB Nest Sauna Room (new from 12/7/18)
# 403   2021-07-16   BNB Nest:1 room with Bath  and 1 room with Sauna
# 420   2021-07-16                                    Duplex Studio E
# 465   2021-07-16                Lovely apartment at the Opera House
# 467   2021-07-16  Central Classy App 4p, free Coffeehouse Breakfast
# 547   2021-07-16      Newly Renovated Cosy Apartment in City Center
# 572   2021-07-16           New Penthouse in the Center of Ghent (2)
# 576   2021-07-16                             LucMoon BnB Ledeberg 1
# 577   2021-07-16                             LucMoon BnB Ledeberg 3
# 596   2021-07-16   Spacious App in the center of Gent with mini gym
# 617   2021-07-16                                 The Grey/Rose Room
# 661   2021-07-16   Smartflats Ghent Central 301 - 2 Bed Duplex Terr
# 674   2021-07-16    Welcome in Ghent: private newly renovated house
# 675   2021-07-16       Comfortable private modern house in the city
# 678   2021-07-16           Cozy and private familyhouse in the city
# 784   2021-07-16                       Room 'Margriet' - B&B Graaf.
# 860   2021-07-16  Smartflats Ghent Central 302 - 1 Bedroom Duple...
#
#                                            description  \
# 122  Rural B&B, 3 rooms, private bathroom (shower a...
# 211  Our flat is a 5 min walk from Dampoort Station...
# 241  Studio Edville Gent biedt verschillende studio...
# 242  Studio Edville Gent biedt verschillende studio...
# 244  Studio Edville Gent biedt verschillende studio...
# 245  Studio Edville Gent biedt verschillende studio...
# 389  Welcome to our luxurious Bed & Breakfast ‘NEST...
# 403  Welcome to our luxurious Bed & Breakfast ‘NEST...
# 420  Self-catered studio on 3th floor with extra me...
# 465  Lovely 1 bedroom apartment right in the city c...
# 467  This is a newly renovated corner apartment in ...
# 547  - Newly renovated apartment with a stylish Sca...
# 572  This newly built apartment is situated in the ...
# 576  Nieuwe, degelijke bedden met lattoflex, ijskas...
# 577  Nieuwe, degelijke bedden met lattoflex, ijskas...
# 596  This super spacious and cozy apartment is loca...
# 617  The accomodation is very near (5 min by walkin...
# 661  Smartflats Ghent is located in the best spot i...
# 674  Our recently renovated house on 5 min from the...
# 675  Our recently renovated house on 5 min from the...
# 678  Our recently renovated house on 5 min from the...
# 784  Graaf. is all about Belgian design. Don't thin...
# 860  Smartflats Ghent is located in the best spot i...
#
#                                  neighborhood_overview  \
# 122  Deurle and St. Martens-Latem (10 km) are two p...
# 211                                                NaN
# 241  Studio Edville Gent is gelegen aan het water i...
# 242  Studio Edville Gent is gelegen aan het water i...
# 244  Studio Edville Gent is gelegen aan het water i...
# 245  Studio Edville Gent is gelegen aan het water i...
# 389  Our B&B Nest is located just outside of the ci...
# 403  Our B&B Nest is located just outside of the ci...
# 420  This studio is situated in a hip upcoming neig...
# 465  Ghent is pretty small and we are right in the ...
# 467  ‘Asking citizens of Ghent what they think of t...
# 547  Experience Ghent from it's beautiful historic ...
# 572                                                NaN
# 576                                                NaN
# 577                                                NaN
# 596  Within a 5-minute walk, you will arrive in the...
# 617                                                NaN
# 661                                                NaN
# 674  There is bus 3 around the corner, in 2 min you...
# 675  There is bus 3 around the corner, in 2 min you...
# 678  There is bus 3 around the corner, in 2 min you...
# 784                                                NaN
# 860                                                NaN
#
#                                            picture_url    host_id  \
# 122  https://a0.muscache.com/pictures/1ac7e92c-20e3...   43671238
# 211  https://a0.muscache.com/pictures/f3ba1f6b-fcd2...    5883895
# 241  https://a0.muscache.com/pictures/c556f91d-8b55...     414263
# 242  https://a0.muscache.com/pictures/56f70957-aa6d...     414263
# 244  https://a0.muscache.com/pictures/8719d90e-105b...     414263
# 245  https://a0.muscache.com/pictures/352bf500-612e...     414263
# 389  https://a0.muscache.com/pictures/52d0526c-3860...   17971943
# 403  https://a0.muscache.com/pictures/b5616f31-40dc...   17971943
# 420  https://a0.muscache.com/pictures/e835d362-dd5a...    1328011
# 465  https://a0.muscache.com/pictures/miso/Hosting-...  110630447
# 467  https://a0.muscache.com/pictures/4e0d9adb-6d2f...   22195789
# 547  https://a0.muscache.com/pictures/5ab5c580-37cf...  105326422
# 572  https://a0.muscache.com/pictures/5368291b-6a8f...  112723296
# 576  https://a0.muscache.com/pictures/7dc42d38-612d...  193703180
# 577  https://a0.muscache.com/pictures/d1327d8e-7bfd...  193703180
# 596  https://a0.muscache.com/pictures/ab3f547b-b025...  201859498
# 617  https://a0.muscache.com/pictures/8cdb8dd9-36bc...  299333776
# 661  https://a0.muscache.com/pictures/miso/Hosting-...    2792958
# 674  https://a0.muscache.com/pictures/9f1c93b3-1142...   36152908
# 675  https://a0.muscache.com/pictures/9ccb1f32-9833...   36152908
# 678  https://a0.muscache.com/pictures/ab6042c6-fa09...   36152908
# 784  https://a0.muscache.com/pictures/miso/Hosting-...   43889699
# 860  https://a0.muscache.com/pictures/prohost-api/H...    2792958
#
#                                         host_url  ... review_scores_location  \
# 122   https://www.airbnb.com/users/show/43671238  ...                   4.67
# 211    https://www.airbnb.com/users/show/5883895  ...                   4.42
# 241     https://www.airbnb.com/users/show/414263  ...                   4.67
# 242     https://www.airbnb.com/users/show/414263  ...                   4.50
# 244     https://www.airbnb.com/users/show/414263  ...                   4.78
# 245     https://www.airbnb.com/users/show/414263  ...                   4.58
# 389   https://www.airbnb.com/users/show/17971943  ...                   4.41
# 403   https://www.airbnb.com/users/show/17971943  ...                   4.17
# 420    https://www.airbnb.com/users/show/1328011  ...                   5.00
# 465  https://www.airbnb.com/users/show/110630447  ...                   4.99
# 467   https://www.airbnb.com/users/show/22195789  ...                   4.95
# 547  https://www.airbnb.com/users/show/105326422  ...                   5.00
# 572  https://www.airbnb.com/users/show/112723296  ...                   5.00
# 576  https://www.airbnb.com/users/show/193703180  ...                   3.00
# 577  https://www.airbnb.com/users/show/193703180  ...                   5.00
# 596  https://www.airbnb.com/users/show/201859498  ...                   5.00
# 617  https://www.airbnb.com/users/show/299333776  ...                   4.00
# 661    https://www.airbnb.com/users/show/2792958  ...                    NaN
# 674   https://www.airbnb.com/users/show/36152908  ...                    NaN
# 675   https://www.airbnb.com/users/show/36152908  ...                    NaN
# 678   https://www.airbnb.com/users/show/36152908  ...                    NaN
# 784   https://www.airbnb.com/users/show/43889699  ...                   4.50
# 860    https://www.airbnb.com/users/show/2792958  ...                    NaN
#
#     review_scores_value license instant_bookable  \
# 122                4.67     NaN                f
# 211                4.75     NaN                f
# 241                3.67     NaN                t
# 242                3.50     NaN                t
# 244                4.22     NaN                t
# 245                4.25     NaN                t
# 389                4.77     NaN                t
# 403                4.83     NaN                f
# 420                4.67     NaN                f
# 465                4.92     NaN                f
# 467                4.88     NaN                t
# 547                4.71     NaN                t
# 572                4.50     NaN                f
# 576                2.00     NaN                t
# 577                4.00     NaN                t
# 596                4.88     NaN                t
# 617                4.33     NaN                f
# 661                 NaN     NaN                t
# 674                 NaN     NaN                f
# 675                 NaN     NaN                f
# 678                 NaN     NaN                f
# 784                5.00     NaN                t
# 860                 NaN     NaN                t
#
#     calculated_host_listings_count  \
# 122                              2
# 211                              7
# 241                              8
# 242                              8
# 244                              8
# 245                              8
# 389                              3
# 403                              3
# 420                              4
# 465                              4
# 467                              4
# 547                              4
# 572                              3
# 576                              4
# 577                              4
# 596                              2
# 617                              5
# 661                              4
# 674                              4
# 675                              4
# 678                              4
# 784                              3
# 860                              4
#
#     calculated_host_listings_count_entire_homes  \
# 122                                           0
# 211                                           7
# 241                                           7
# 242                                           7
# 244                                           7
# 245                                           7
# 389                                           0
# 403                                           0
# 420                                           4
# 465                                           3
# 467                                           3
# 547                                           4
# 572                                           0
# 576                                           0
# 577                                           0
# 596                                           1
# 617                                           0
# 661                                           4
# 674                                           4
# 675                                           4
# 678                                           4
# 784                                           0
# 860                                           4
#
#     calculated_host_listings_count_private_rooms  \
# 122                                            2
# 211                                            0
# 241                                            0
# 242                                            0
# 244                                            0
# 245                                            0
# 389                                            0
# 403                                            0
# 420                                            0
# 465                                            1
# 467                                            1
# 547                                            0
# 572                                            3
# 576                                            4
# 577                                            4
# 596                                            1
# 617                                            5
# 661                                            0
# 674                                            0
# 675                                            0
# 678                                            0
# 784                                            3
# 860                                            0
#
#     calculated_host_listings_count_shared_rooms reviews_per_month Unnamed: 74
# 122                                         0.0              0.19         NaN
# 211                                         0.0              2.38         NaN
# 241                                         0.0              0.08         NaN
# 242                                         0.0              0.05         NaN
# 244                                         0.0              0.24         NaN
# 245                                         0.0              0.28         NaN
# 389                                         0.0              1.20         NaN
# 403                                         0.0              0.17         NaN
# 420                                         0.0              0.18         NaN
# 465                                         0.0              3.81         NaN
# 467                                         0.0              2.41         NaN
# 547                                         0.0              1.78         NaN
# 572                                         0.0              0.23         NaN
# 576                                         0.0              0.05         NaN
# 577                                         0.0              0.05         NaN
# 596                                         0.0              0.41         NaN
# 617                                         0.0              0.16         NaN
# 661                                         0.0               NaN         NaN
# 674                                         0.0               NaN         NaN
# 675                                         0.0               NaN         NaN
# 678                                         0.0               NaN         NaN
# 784                                         0.0              0.31         NaN
# 860                                         0.0               NaN         NaN
#
# [23 rows x 75 columns]

# %% [markdown]
# ## Extract keywords from reviews / descriptions
#
# TODO WRITE INTRO

# %% [markdown]
# ### Import packages and English stop words

# %%
import math
import nltk

from nltk import tokenize
from operator import itemgetter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# this has to be run once (its a download)
# nltk.download('stopwords')

#TODO EXTEND TO DUTCH (THE DOWNLOAD HAS DUTCH STOPWORDS ASWELL)

stop_words = set(stopwords.words('english'))
# Out:
# 0    The top floor of our house in the center of Gh...
# 1    This well-located and comfortable one-bedroom ...
# Name: description, dtype: object

# %% [markdown]
# ### Find total number of words and sentences
# These will be used later for TF and IDF

# %%
#for testing purposes
sample_review = "This is a great little apartment, a 10 minute walk from the town centre and close to the canal. It has everything that you would need. I stayed for 3 weeks and it was super comfortable. Jeroen is a great host, providing a wealth of information on the local area and tourist advice for visiting the sights. The no.2. tram stops right outside the apartment which is super convenient for Sint Pieter's station. The Van Hecke bakery across the road is great, as is the frituur (amazing chips!). There's also a lovely quiet spot to sit by the canal if you walk down Iepenstraat. The only negatives for me are that the walls/windows are a little thin, so (as a light sleeper) I could hear the road and my neighbour quite late at night (with earplugs though it was not a problem). For the kitchen, be aware that the oven is actually a microwave/grill (in case you are preparing a meal plan in advance), and there are no scales or measuring jugs. Otherwise everything was perfect and I would happily return to stay there again!"
total_words = sample_review.split()
total_word_length = len(total_words)
print("The total number of words is " + str(total_word_length))

# this needs to be done once before using tokenize
# todo move this somewhere
nltk.download('punkt')

total_sentences = tokenize.sent_tokenize(sample_review)
total_sent_len = len(total_sentences)
print("The total number of sentences is " + str(total_sent_len))
# Out:
# The total number of words is 185
# The total number of sentences is 11
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\p_kuk\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Calculate TF for each word

# %%
tf_score = {}
for each_word in total_words:
    each_word = each_word.replace('.','')
    if each_word not in stop_words:
        if each_word in tf_score:
            tf_score[each_word] += 1
        else:
            tf_score[each_word] = 1

# Dividing by total_word_length for each dictionary element
tf_score.update((x, y/int(total_word_length)) for x, y in tf_score.items())
print(tf_score)
# Out:
# {'This': 0.005405405405405406, 'great': 0.010810810810810811, 'little': 0.010810810810810811, 'apartment,': 0.005405405405405406, '10': 0.005405405405405406, 'minute': 0.005405405405405406, 'walk': 0.010810810810810811, 'town': 0.005405405405405406, 'centre': 0.005405405405405406, 'close': 0.005405405405405406, 'canal': 0.010810810810810811, 'It': 0.005405405405405406, 'everything': 0.010810810810810811, 'would': 0.010810810810810811, 'need': 0.005405405405405406, 'I': 0.016216216216216217, 'stayed': 0.005405405405405406, '3': 0.005405405405405406, 'weeks': 0.005405405405405406, 'super': 0.010810810810810811, 'comfortable': 0.005405405405405406, 'Jeroen': 0.005405405405405406, 'host,': 0.005405405405405406, 'providing': 0.005405405405405406, 'wealth': 0.005405405405405406, 'information': 0.005405405405405406, 'local': 0.005405405405405406, 'area': 0.005405405405405406, 'tourist': 0.005405405405405406, 'advice': 0.005405405405405406, 'visiting': 0.005405405405405406, 'sights': 0.005405405405405406, 'The': 0.016216216216216217, 'no2': 0.005405405405405406, 'tram': 0.005405405405405406, 'stops': 0.005405405405405406, 'right': 0.005405405405405406, 'outside': 0.005405405405405406, 'apartment': 0.005405405405405406, 'convenient': 0.005405405405405406, 'Sint': 0.005405405405405406, "Pieter's": 0.005405405405405406, 'station': 0.005405405405405406, 'Van': 0.005405405405405406, 'Hecke': 0.005405405405405406, 'bakery': 0.005405405405405406, 'across': 0.005405405405405406, 'road': 0.010810810810810811, 'great,': 0.005405405405405406, 'frituur': 0.005405405405405406, '(amazing': 0.005405405405405406, 'chips!)': 0.005405405405405406, "There's": 0.005405405405405406, 'also': 0.005405405405405406, 'lovely': 0.005405405405405406, 'quiet': 0.005405405405405406, 'spot': 0.005405405405405406, 'sit': 0.005405405405405406, 'Iepenstraat': 0.005405405405405406, 'negatives': 0.005405405405405406, 'walls/windows': 0.005405405405405406, 'thin,': 0.005405405405405406, '(as': 0.005405405405405406, 'light': 0.005405405405405406, 'sleeper)': 0.005405405405405406, 'could': 0.005405405405405406, 'hear': 0.005405405405405406, 'neighbour': 0.005405405405405406, 'quite': 0.005405405405405406, 'late': 0.005405405405405406, 'night': 0.005405405405405406, '(with': 0.005405405405405406, 'earplugs': 0.005405405405405406, 'though': 0.005405405405405406, 'problem)': 0.005405405405405406, 'For': 0.005405405405405406, 'kitchen,': 0.005405405405405406, 'aware': 0.005405405405405406, 'oven': 0.005405405405405406, 'actually': 0.005405405405405406, 'microwave/grill': 0.005405405405405406, '(in': 0.005405405405405406, 'case': 0.005405405405405406, 'preparing': 0.005405405405405406, 'meal': 0.005405405405405406, 'plan': 0.005405405405405406, 'advance),': 0.005405405405405406, 'scales': 0.005405405405405406, 'measuring': 0.005405405405405406, 'jugs': 0.005405405405405406, 'Otherwise': 0.005405405405405406, 'perfect': 0.005405405405405406, 'happily': 0.005405405405405406, 'return': 0.005405405405405406, 'stay': 0.005405405405405406, 'again!': 0.005405405405405406}

# %% [markdown]
#  ### Calculate IDF for each word

# %%
def check_sent(word, sentences): #helper function
    final = [all([w in x for w in word]) for x in sentences] 
    sent_len = [sentences[i] for i in range(0, len(final)) if final[i]]
    return int(len(sent_len))

idf_score = {}
for each_word in total_words:
    each_word = each_word.replace('.','')
    if each_word not in stop_words:
        if each_word in idf_score:
            idf_score[each_word] = check_sent(each_word, total_sentences)
        else:
            idf_score[each_word] = 1

# Performing a log and divide
idf_score.update((x, math.log(int(total_sent_len)/y)) for x, y in idf_score.items())

print(idf_score)
# Out:
# {'This': 2.3978952727983707, 'great': 0.3184537311185346, 'little': 0.3184537311185346, 'apartment,': 2.3978952727983707, '10': 2.3978952727983707, 'minute': 2.3978952727983707, 'walk': 1.0116009116784799, 'town': 2.3978952727983707, 'centre': 2.3978952727983707, 'close': 2.3978952727983707, 'canal': 0.4519851237430572, 'It': 2.3978952727983707, 'everything': 1.0116009116784799, 'would': 0.3184537311185346, 'need': 2.3978952727983707, 'I': 0.7884573603642703, 'stayed': 2.3978952727983707, '3': 2.3978952727983707, 'weeks': 2.3978952727983707, 'super': 0.20067069546215124, 'comfortable': 2.3978952727983707, 'Jeroen': 2.3978952727983707, 'host,': 2.3978952727983707, 'providing': 2.3978952727983707, 'wealth': 2.3978952727983707, 'information': 2.3978952727983707, 'local': 2.3978952727983707, 'area': 2.3978952727983707, 'tourist': 2.3978952727983707, 'advice': 2.3978952727983707, 'visiting': 2.3978952727983707, 'sights': 2.3978952727983707, 'The': 0.7884573603642703, 'no2': 2.3978952727983707, 'tram': 2.3978952727983707, 'stops': 2.3978952727983707, 'right': 2.3978952727983707, 'outside': 2.3978952727983707, 'apartment': 2.3978952727983707, 'convenient': 2.3978952727983707, 'Sint': 2.3978952727983707, "Pieter's": 2.3978952727983707, 'station': 2.3978952727983707, 'Van': 2.3978952727983707, 'Hecke': 2.3978952727983707, 'bakery': 2.3978952727983707, 'across': 2.3978952727983707, 'road': 0.09531017980432493, 'great,': 2.3978952727983707, 'frituur': 2.3978952727983707, '(amazing': 2.3978952727983707, 'chips!)': 2.3978952727983707, "There's": 2.3978952727983707, 'also': 2.3978952727983707, 'lovely': 2.3978952727983707, 'quiet': 2.3978952727983707, 'spot': 2.3978952727983707, 'sit': 2.3978952727983707, 'Iepenstraat': 2.3978952727983707, 'negatives': 2.3978952727983707, 'walls/windows': 2.3978952727983707, 'thin,': 2.3978952727983707, '(as': 2.3978952727983707, 'light': 2.3978952727983707, 'sleeper)': 2.3978952727983707, 'could': 2.3978952727983707, 'hear': 2.3978952727983707, 'neighbour': 2.3978952727983707, 'quite': 2.3978952727983707, 'late': 2.3978952727983707, 'night': 2.3978952727983707, '(with': 2.3978952727983707, 'earplugs': 2.3978952727983707, 'though': 2.3978952727983707, 'problem)': 2.3978952727983707, 'For': 2.3978952727983707, 'kitchen,': 2.3978952727983707, 'aware': 2.3978952727983707, 'oven': 2.3978952727983707, 'actually': 2.3978952727983707, 'microwave/grill': 2.3978952727983707, '(in': 2.3978952727983707, 'case': 2.3978952727983707, 'preparing': 2.3978952727983707, 'meal': 2.3978952727983707, 'plan': 2.3978952727983707, 'advance),': 2.3978952727983707, 'scales': 2.3978952727983707, 'measuring': 2.3978952727983707, 'jugs': 2.3978952727983707, 'Otherwise': 2.3978952727983707, 'perfect': 2.3978952727983707, 'happily': 2.3978952727983707, 'return': 2.3978952727983707, 'stay': 2.3978952727983707, 'again!': 2.3978952727983707}

# %% [markdown]
# ### Calculate TF*IDF

# %%
tf_idf_score = {key: tf_score[key] * idf_score.get(key, 0) for key in tf_score.keys()}
print(tf_idf_score)
# Out:
# {'This': 0.012961596069180382, 'great': 0.003442743039119293, 'little': 0.003442743039119293, 'apartment,': 0.012961596069180382, '10': 0.012961596069180382, 'minute': 0.012961596069180382, 'walk': 0.010936226072199783, 'town': 0.012961596069180382, 'centre': 0.012961596069180382, 'close': 0.012961596069180382, 'canal': 0.004886325662087105, 'It': 0.012961596069180382, 'everything': 0.010936226072199783, 'would': 0.003442743039119293, 'need': 0.012961596069180382, 'I': 0.012785795032934113, 'stayed': 0.012961596069180382, '3': 0.012961596069180382, 'weeks': 0.012961596069180382, 'super': 0.0021694129239151487, 'comfortable': 0.012961596069180382, 'Jeroen': 0.012961596069180382, 'host,': 0.012961596069180382, 'providing': 0.012961596069180382, 'wealth': 0.012961596069180382, 'information': 0.012961596069180382, 'local': 0.012961596069180382, 'area': 0.012961596069180382, 'tourist': 0.012961596069180382, 'advice': 0.012961596069180382, 'visiting': 0.012961596069180382, 'sights': 0.012961596069180382, 'The': 0.012785795032934113, 'no2': 0.012961596069180382, 'tram': 0.012961596069180382, 'stops': 0.012961596069180382, 'right': 0.012961596069180382, 'outside': 0.012961596069180382, 'apartment': 0.012961596069180382, 'convenient': 0.012961596069180382, 'Sint': 0.012961596069180382, "Pieter's": 0.012961596069180382, 'station': 0.012961596069180382, 'Van': 0.012961596069180382, 'Hecke': 0.012961596069180382, 'bakery': 0.012961596069180382, 'across': 0.012961596069180382, 'road': 0.0010303803222089182, 'great,': 0.012961596069180382, 'frituur': 0.012961596069180382, '(amazing': 0.012961596069180382, 'chips!)': 0.012961596069180382, "There's": 0.012961596069180382, 'also': 0.012961596069180382, 'lovely': 0.012961596069180382, 'quiet': 0.012961596069180382, 'spot': 0.012961596069180382, 'sit': 0.012961596069180382, 'Iepenstraat': 0.012961596069180382, 'negatives': 0.012961596069180382, 'walls/windows': 0.012961596069180382, 'thin,': 0.012961596069180382, '(as': 0.012961596069180382, 'light': 0.012961596069180382, 'sleeper)': 0.012961596069180382, 'could': 0.012961596069180382, 'hear': 0.012961596069180382, 'neighbour': 0.012961596069180382, 'quite': 0.012961596069180382, 'late': 0.012961596069180382, 'night': 0.012961596069180382, '(with': 0.012961596069180382, 'earplugs': 0.012961596069180382, 'though': 0.012961596069180382, 'problem)': 0.012961596069180382, 'For': 0.012961596069180382, 'kitchen,': 0.012961596069180382, 'aware': 0.012961596069180382, 'oven': 0.012961596069180382, 'actually': 0.012961596069180382, 'microwave/grill': 0.012961596069180382, '(in': 0.012961596069180382, 'case': 0.012961596069180382, 'preparing': 0.012961596069180382, 'meal': 0.012961596069180382, 'plan': 0.012961596069180382, 'advance),': 0.012961596069180382, 'scales': 0.012961596069180382, 'measuring': 0.012961596069180382, 'jugs': 0.012961596069180382, 'Otherwise': 0.012961596069180382, 'perfect': 0.012961596069180382, 'happily': 0.012961596069180382, 'return': 0.012961596069180382, 'stay': 0.012961596069180382, 'again!': 0.012961596069180382}

# %% [markdown]
# ### Get the X most significant words

# %%
def get_top_n(dict_elem, n):
    result = dict(sorted(dict_elem.items(), key = itemgetter(1), reverse = True)[:n]) 
    return result

print(get_top_n(tf_idf_score, 5))
# Out:
# {'This': 0.012961596069180382, 'apartment,': 0.012961596069180382, '10': 0.012961596069180382, 'minute': 0.012961596069180382, 'town': 0.012961596069180382}

# %% [markdown]
# ## Keyword extraction from descriptions using TF-IDF
#
# TODO explanation
#
# TODO expand to reviews aswell

# %%
import texthero as hero
listings['tfidf'] = hero.tfidf(listings['description'])
listings.head(2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7368/3494799846.py in <module>
# ----> 1 import texthero as hero
#       2 listings['tfidf'] = hero.tfidf(listings['description'])
#       3 listings.head(2)
#
# ModuleNotFoundError: No module named 'texthero'
